# %% [markdown]
# # Data Cleaning for Visualization Dashboard Project

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## Exploring the Dataset

# %% [markdown]
# ### Bring in the JSON Dataset

# %%
superfund_sites_file = "Datasets/priorities_list_full.json"
superfund_sites_df = pd.read_json(superfund_sites_file)

# %% [markdown]
# ### Create a list of column names
# We copy this list over to a spreadsheet to compare it with simialr lists from the census data files. Notably, the JSON file includes both census block and tract IDs, along with the full FIPS code. It is especially convenient that the JSON file includes data of particular interest, including the latidtude and longitude of each site, the site ID, the site 'score', and socioeconomic values for the population within the same census boundaries.

# %%
superfund_column_names = list(superfund_sites_df.columns.values)
superfund_column_names
# Out:
# ['FIPS_Full',
#  'address',
#  'city',
#  'date_added',
#  'federal_facility_ind',
#  'federal_register_url',
#  'geocode_source',
#  'latitude',
#  'longitude',
#  'site_epa_id',
#  'site_name',
#  'site_narrative_url',
#  'site_progress_url',
#  'site_score',
#  'text',
#  'FIPS_Block_Group',
#  'State',
#  'State_name',
#  'County',
#  'County_name',
#  'Tract',
#  'Block_Group',
#  'Flag',
#  'LAND_AREA',
#  'AIAN_LAND',
#  'URBANIZED_AREA_POP_CEN_2010',
#  'URBAN_CLUSTER_POP_CEN_2010',
#  'RURAL_POP_CEN_2010',
#  'Tot_Population_CEN_2010',
#  'Tot_Population_ACS_09_13',
#  'Tot_Population_ACSMOE_09_13',
#  'Males_CEN_2010',
#  'Males_ACS_09_13',
#  'Males_ACSMOE_09_13',
#  'Females_CEN_2010',
#  'Females_ACS_09_13',
#  'Females_ACSMOE_09_13',
#  'Pop_under_5_CEN_2010',
#  'Pop_under_5_ACS_09_13',
#  'Pop_under_5_ACSMOE_09_13',
#  'Pop_5_17_CEN_2010',
#  'Pop_5_17_ACS_09_13',
#  'Pop_5_17_ACSMOE_09_13',
#  'Pop_18_24_CEN_2010',
#  'Pop_18_24_ACS_09_13',
#  'Pop_18_24_ACSMOE_09_13',
#  'Pop_25_44_CEN_2010',
#  'Pop_25_44_ACS_09_13',
#  'Pop_25_44_ACSMOE_09_13',
#  'Pop_45_64_CEN_2010',
#  'Pop_45_64_ACS_09_13',
#  'Pop_45_64_ACSMOE_09_13',
#  'Pop_65plus_CEN_2010',
#  'Pop_65plus_ACS_09_13',
#  'Pop_65plus_ACSMOE_09_13',
#  'Tot_GQ_CEN_2010',
#  'Inst_GQ_CEN_2010',
#  'Non_Inst_GQ_CEN_2010',
#  'Hispanic_CEN_2010',
#  'Hispanic_ACS_09_13',
#  'Hispanic_ACSMOE_09_13',
#  'NH_White_alone_CEN_2010',
#  'NH_White_alone_ACS_09_13',
#  'NH_White_alone_ACSMOE_09_13',
#  'NH_Blk_alone_CEN_2010',
#  'NH_Blk_alone_ACS_09_13',
#  'NH_Blk_alone_ACSMOE_09_13',
#  'NH_AIAN_alone_CEN_2010',
#  'NH_AIAN_alone_ACS_09_13',
#  'NH_AIAN_alone_ACSMOE_09_13',
#  'NH_Asian_alone_CEN_2010',
#  'NH_Asian_alone_ACS_09_13',
#  'NH_Asian_alone_ACSMOE_09_13',
#  'NH_NHOPI_alone_CEN_2010',
#  'NH_NHOPI_alone_ACS_09_13',
#  'NH_NHOPI_alone_ACSMOE_09_13',
#  'NH_SOR_alone_CEN_2010',
#  'NH_SOR_alone_ACS_09_13',
#  'NH_SOR_alone_ACSMOE_09_13',
#  'Pop_5yrs_Over_ACS_09_13',
#  'Pop_5yrs_Over_ACSMOE_09_13',
#  'Othr_Lang_ACS_09_13',
#  'Othr_Lang_ACSMOE_09_13',
#  'Pop_25yrs_Over_ACS_09_13',
#  'Pop_25yrs_Over_ACSMOE_09_13',
#  'Not_HS_Grad_ACS_09_13',
#  'Not_HS_Grad_ACSMOE_09_13',
#  'College_ACS_09_13',
#  'College_ACSMOE_09_13',
#  'Pov_Univ_ACS_09_13',
#  'Pov_Univ_ACSMOE_09_13',
#  'Prs_Blw_Pov_Lev_ACS_09_13',
#  'Prs_Blw_Pov_Lev_ACSMOE_09_13',
#  'One_Health_Ins_ACS_09_13',
#  'One_Health_Ins_ACSMOE_09_13',
#  'Two_Plus_Health_Ins_ACS_09_13',
#  'Two_Plus_Health_Ins_ACSMOE_09_13',
#  'No_Health_Ins_ACS_09_13',
#  'No_Health_Ins_ACSMOE_09_13',
#  'Pop_1yr_Over_ACS_09_13',
#  'Pop_1yr_Over_ACSMOE_09_13',
#  'Diff_HU_1yr_Ago_ACS_09_13',
#  'Diff_HU_1yr_Ago_ACSMOE_09_13',
#  'ENG_VW_SPAN_ACS_09_13',
#  'ENG_VW_SPAN_ACSMOE_09_13',
#  'ENG_VW_INDO_EURO_ACS_09_13',
#  'ENG_VW_INDO_EURO_ACSMOE_09_13',
#  'ENG_VW_API_ACS_09_13',
#  'ENG_VW_API_ACSMOE_09_13',
#  'ENG_VW_OTHER_ACS_09_13',
#  'ENG_VW_OTHER_ACSMOE_09_13',
#  'ENG_VW_ACS_09_13',
#  'ENG_VW_ACSMOE_09_13',
#  'Rel_Family_HHDS_CEN_2010',
#  'Rel_Family_HHD_ACS_09_13',
#  'Rel_Family_HHD_ACSMOE_09_13',
#  'MrdCple_Fmly_HHD_CEN_2010',
#  'MrdCple_Fmly_HHD_ACS_09_13',
#  'MrdCple_Fmly_HHD_ACSMOE_09_13',
#  'Not_MrdCple_HHD_CEN_2010',
#  'Not_MrdCple_HHD_ACS_09_13',
#  'Not_MrdCple_HHD_ACSMOE_09_13',
#  'Female_No_HB_CEN_2010',
#  'Female_No_HB_ACS_09_13',
#  'Female_No_HB_ACSMOE_09_13',
#  'NonFamily_HHD_CEN_2010',
#  'NonFamily_HHD_ACS_09_13',
#  'NonFamily_HHD_ACSMOE_09_13',
#  'Sngl_Prns_HHD_CEN_2010',
#  'Sngl_Prns_HHD_ACS_09_13',
#  'Sngl_Prns_HHD_ACSMOE_09_13',
#  'HHD_PPL_Und_18_CEN_2010',
#  'HHD_PPL_Und_18_ACS_09_13',
#  'HHD_PPL_Und_18_ACSMOE_09_13',
#  'Tot_Prns_in_HHD_CEN_2010',
#  'Tot_Prns_in_HHD_ACS_09_13',
#  'Tot_Prns_in_HHD_ACSMOE_09_13',
#  'Rel_Child_Under_6_CEN_2010',
#  'Rel_Child_Under_6_ACS_09_13',
#  'Rel_Child_Under_6_ACSMOE_09_13',
#  'HHD_Moved_in_ACS_09_13',
#  'HHD_Moved_in_ACSMOE_09_13',
#  'PUB_ASST_INC_ACS_09_13',
#  'PUB_ASST_INC_ACSMOE_09_13',
#  'Med_HHD_Inc_BG_ACS_09_13',
#  'Med_HHD_Inc_BG_ACSMOE_09_13',
#  'Med_HHD_Inc_TR_ACS_09_13',
#  'Med_HHD_Inc_TR_ACSMOE_09_13',
#  'Aggregate_HH_INC_ACS_09_13',
#  'Aggregate_HH_INC_ACSMOE_09_13',
#  'Tot_Housing_Units_CEN_2010',
#  'Tot_Housing_Units_ACS_09_13',
#  'Tot_Housing_Units_ACSMOE_09_13',
#  'Tot_Occp_Units_CEN_2010',
#  'Tot_Occp_Units_ACS_09_13',
#  'Tot_Occp_Units_ACSMOE_09_13',
#  'Tot_Vacant_Units_CEN_2010',
#  'Tot_Vacant_Units_ACS_09_13',
#  'Tot_Vacant_Units_ACSMOE_09_13',
#  'Renter_Occp_HU_CEN_2010',
#  'Renter_Occp_HU_ACS_09_13',
#  'Renter_Occp_HU_ACSMOE_09_13',
#  'Owner_Occp_HU_CEN_2010',
#  'Owner_Occp_HU_ACS_09_13',
#  'Owner_Occp_HU_ACSMOE_09_13',
#  'Single_Unit_ACS_09_13',
#  'Single_Unit_ACSMOE_09_13',
#  'MLT_U2_9_STRC_ACS_09_13',
#  'MLT_U2_9_STRC_ACSMOE_09_13',
#  'MLT_U10p_ACS_09_13',
#  'MLT_U10p_ACSMOE_09_13',
#  'Mobile_Homes_ACS_09_13',
#  'Mobile_Homes_ACSMOE_09_13',
#  'Crowd_Occp_U_ACS_09_13',
#  'Crowd_Occp_U_ACSMOE_09_13',
#  'Occp_U_NO_PH_SRVC_ACS_09_13',
#  'Occp_U_NO_PH_SRVC_ACSMOE_09_13',
#  'No_Plumb_ACS_09_13',
#  'No_Plumb_ACSMOE_09_13',
#  'Recent_Built_HU_ACS_09_13',
#  'Recent_Built_HU_ACSMOE_09_13',
#  'Med_House_Value_BG_ACS_09_13',
#  'Med_House_Value_BG_ACSMOE_09_13',
#  'Med_house_value_TR_ACS_09_13',
#  'Med_house_value_TR_ACSMOE_09_13',
#  'Aggr_House_Value_ACS_09_13',
#  'Aggr_House_Value_ACSMOE_09_13',
#  'MailBack_Area_Count_CEN_2010',
#  'TEA_Mail_Out_Mail_Back_CEN_2010',
#  'TEA_Update_Leave_CEN_2010',
#  'Census_Mail_Returns_CEN_2010',
#  'Vacants_CEN_2010',
#  'Deletes_CEN_2010',
#  'Census_UAA_CEN_2010',
#  'Valid_Mailback_Count_CEN_2010',
#  'FRST_FRMS_CEN_2010',
#  'RPLCMNT_FRMS_CEN_2010',
#  'BILQ_Mailout_count_CEN_2010',
#  'BILQ_Frms_CEN_2010',
#  'Mail_Return_Rate_CEN_2010',
#  'Low_Response_Score',
#  'pct_URBANIZED_AREA_POP_CEN_2010',
#  'pct_URBAN_CLUSTER_POP_CEN_2010',
#  'pct_RURAL_POP_CEN_2010',
#  'pct_Males_CEN_2010',
#  'pct_Males_ACS_09_13',
#  'pct_Males_ACSMOE_09_13',
#  'pct_Females_CEN_2010',
#  'pct_Females_ACS_09_13',
#  'pct_Females_ACSMOE_09_13',
#  'pct_Pop_Under_5_CEN_2010',
#  'pct_Pop_Under_5_ACS_09_13',
#  'pct_Pop_Under_5_ACSMOE_09_13',
#  'pct_Pop_5_17_CEN_2010',
#  'pct_Pop_5_17_ACS_09_13',
#  'pct_Pop_5_17_ACSMOE_09_13',
#  'pct_Pop_18_24_CEN_2010',
#  'pct_Pop_18_24_ACS_09_13',
#  'pct_Pop_18_24_ACSMOE_09_13',
#  'pct_Pop_25_44_CEN_2010',
#  'pct_Pop_25_44_ACS_09_13',
#  'pct_Pop_25_44_ACSMOE_09_13',
#  'pct_Pop_45_64_CEN_2010',
#  'pct_Pop_45_64_ACS_09_13',
#  'pct_Pop_45_64_ACSMOE_09_13',
#  'pct_Pop_65plus_CEN_2010',
#  'pct_Pop_65plus_ACS_09_13',
#  'pct_Pop_65plus_ACSMOE_09_13',
#  'pct_Tot_GQ_CEN_2010',
#  'pct_Inst_GQ_CEN_2010',
#  'pct_Non_Inst_GQ_CEN_2010',
#  'pct_Hispanic_CEN_2010',
#  'pct_Hispanic_ACS_09_13',
#  'pct_Hispanic_ACSMOE_09_13',
#  'pct_NH_White_alone_CEN_2010',
#  'pct_NH_White_alone_ACS_09_13',
#  'pct_NH_White_alone_ACSMOE_09_13',
#  'pct_NH_Blk_alone_CEN_2010',
#  'pct_NH_Blk_alone_ACS_09_13',
#  'pct_NH_Blk_alone_ACSMOE_09_13',
#  'pct_NH_AIAN_alone_CEN_2010',
#  'pct_NH_AIAN_alone_ACS_09_13',
#  'pct_NH_AIAN_alone_ACSMOE_09_13',
#  'pct_NH_Asian_alone_CEN_2010',
#  'pct_NH_Asian_alone_ACS_09_13',
#  'pct_NH_Asian_alone_ACSMOE_09_13',
#  'pct_NH_NHOPI_alone_CEN_2010',
#  'pct_NH_NHOPI_alone_ACS_09_13',
#  'pct_NH_NHOPI_alone_ACSMOE_09_13',
#  'pct_NH_SOR_alone_CEN_2010',
#  'pct_NH_SOR_alone_ACS_09_13',
#  'pct_NH_SOR_alone_ACSMOE_09_13',
#  'pct_Pop_5yrs_Over_ACS_09_13',
#  'pct_Pop_5yrs_Over_ACSMOE_09_13',
#  'pct_Othr_Lang_ACS_09_13',
#  'pct_Othr_Lang_ACSMOE_09_13',
#  'pct_Pop_25yrs_Over_ACS_09_13',
#  'pct_Pop_25yrs_Over_ACSMOE_09_13',
#  'pct_Not_HS_Grad_ACS_09_13',
#  'pct_Not_HS_Grad_ACSMOE_09_13',
#  'pct_College_ACS_09_13',
#  'pct_College_ACSMOE_09_13',
#  'pct_Prs_Blw_Pov_Lev_ACS_09_13',
#  'pct_Prs_Blw_Pov_Lev_ACSMOE_09_13',
#  'pct_One_Health_Ins_ACS_09_13',
#  'pct_One_Health_Ins_ACSMOE_09_13',
#  'pct_TwoPHealth_Ins_ACS_09_13',
#  'pct_TwoPHealthIns_ACSMOE_09_13',
#  'pct_No_Health_Ins_ACS_09_13',
#  'pct_No_Health_Ins_ACSMOE_09_13',
#  'pct_Pov_Univ_ACS_09_13',
#  'pct_Pov_Univ_ACSMOE_09_13',
#  'pct_Pop_1yr_Over_ACS_09_13',
#  'pct_Pop_1yr_Over_ACSMOE_09_13',
#  'pct_Diff_HU_1yr_Ago_ACS_09_13',
#  'pct_Diff_HU_1yr_Ago_ACSMOE_09_13',
#  'pct_ENG_VW_SPAN_ACS_09_13',
#  'pct_ENG_VW_SPAN_ACSMOE_09_13',
#  'pct_ENG_VW_INDOEURO_ACS_09_13',
#  'pct_ENG_VW_INDOEURO_ACSMOE_09_13',
#  'pct_ENG_VW_API_ACS_09_13',
#  'pct_ENG_VW_API_ACSMOE_09_13',
#  'pct_ENG_VW_OTHER_ACS_09_13',
#  'pct_ENG_VW_OTHER_ACSMOE_09_13',
#  'pct_ENG_VW_ACS_09_13',
#  'pct_ENG_VW_ACSMOE_09_13',
#  'pct_Rel_Family_HHDS_CEN_2010',
#  'pct_Rel_Family_HHD_ACS_09_13',
#  'pct_Rel_Family_HHD_ACSMOE_09_13',
#  'pct_MrdCple_HHD_CEN_2010',
#  'pct_MrdCple_HHD_ACS_09_13',
#  'pct_MrdCple_HHD_ACSMOE_09_13',
#  'pct_Not_MrdCple_HHD_CEN_2010',
#  'pct_Not_MrdCple_HHD_ACS_09_13',
#  'pct_Not_MrdCple_HHD_ACSMOE_09_13',
#  'pct_Female_No_HB_CEN_2010',
#  'pct_Female_No_HB_ACS_09_13',
#  'pct_Female_No_HB_ACSMOE_09_13',
#  'pct_NonFamily_HHD_CEN_2010',
#  'pct_NonFamily_HHD_ACS_09_13',
#  'pct_NonFamily_HHD_ACSMOE_09_13',
#  'pct_Sngl_Prns_HHD_CEN_2010',
#  'pct_Sngl_Prns_HHD_ACS_09_13',
#  'pct_Sngl_Prns_HHD_ACSMOE_09_13',
#  'pct_HHD_PPL_Und_18_CEN_2010',
#  'pct_HHD_PPL_Und_18_ACS_09_13',
#  'pct_HHD_PPL_Und_18_ACSMOE_09_13',
#  'avg_Tot_Prns_in_HHD_CEN_2010',
#  'avg_Tot_Prns_in_HHD_ACS_09_13',
#  'avg_Tot_Prns_in_HHD_ACSMOE_09_13',
#  'pct_Rel_Under_6_CEN_2010',
#  'pct_Rel_Under_6_ACS_09_13',
#  'pct_Rel_Under_6_ACSMOE_09_13',
#  'pct_HHD_Moved_in_ACS_09_13',
#  'pct_HHD_Moved_in_ACSMOE_09_13',
#  'pct_PUB_ASST_INC_ACS_09_13',
#  'pct_PUB_ASST_INC_ACSMOE_09_13',
#  'avg_Agg_HH_INC_ACS_09_13',
#  'avg_Agg_HH_INC_ACSMOE_09_13',
#  'pct_Tot_Occp_Units_CEN_2010',
#  'pct_Tot_Occp_Units_ACS_09_13',
#  'pct_Tot_Occp_Units_ACSMOE_09_13',
#  'pct_Vacant_Units_CEN_2010',
#  'pct_Vacant_Units_ACS_09_13',
#  'pct_Vacant_Units_ACSMOE_09_13',
#  'pct_Renter_Occp_HU_CEN_2010',
#  'pct_Renter_Occp_HU_ACS_09_13',
#  'pct_Renter_Occp_HU_ACSMOE_09_13',
#  'pct_Owner_Occp_HU_CEN_2010',
#  'pct_Owner_Occp_HU_ACS_09_13',
#  'pct_Owner_Occp_HU_ACSMOE_09_13',
#  'pct_Single_Unit_ACS_09_13',
#  'pct_Single_Unit_ACSMOE_09_13',
#  'pct_MLT_U2_9_STRC_ACS_09_13',
#  'pct_MLT_U2_9_STRC_ACSMOE_09_13',
#  'pct_MLT_U10p_ACS_09_13',
#  'pct_MLT_U10p_ACSMOE_09_13',
#  'pct_Mobile_Homes_ACS_09_13',
#  'pct_Mobile_Homes_ACSMOE_09_13',
#  'pct_Crowd_Occp_U_ACS_09_13',
#  'pct_Crowd_Occp_U_ACSMOE_09_13',
#  'pct_NO_PH_SRVC_ACS_09_13',
#  'pct_NO_PH_SRVC_ACSMOE_09_13',
#  'pct_No_Plumb_ACS_09_13',
#  'pct_No_Plumb_ACSMOE_09_13',
#  'pct_Recent_Built_HU_ACS_09_13',
#  'pct_Recent_Built_HU_ACSMOE_09_13',
#  'avg_Agg_House_Value_ACS_09_13',
#  'avg_Agg_House_Value_ACSMOE_09_13',
#  'pct_TEA_MailOutMailBack_CEN_2010',
#  'pct_TEA_Update_Leave_CEN_2010',
#  'pct_Census_Mail_Returns_CEN_2010',
#  'pct_Vacant_CEN_2010',
#  'pct_Deletes_CEN_2010',
#  'pct_Census_UAA_CEN_2010',
#  'pct_Mailback_Count_CEN_2010',
#  'pct_FRST_FRMS_CEN_2010',
#  'pct_RPLCMNT_FRMS_CEN_2010',
#  'pct_BILQ_Mailout_count_CEN_2010']

# %% [markdown]
# ### Create a list of column types
# All the JSON data came in as either integers, strings, or floats.

# %%
superfund_column_types = list(superfund_sites_df.dtypes)
superfund_column_types
# Out:
# [dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64')]

# %% [markdown]
# ### Take a peek at the head

# %%
superfund_sites_df.head()
# Out:
#          FIPS_Full                                            address  \
# 0   11210113001044              STATE HWY 235, CHILDERSBURG, AL 35044
# 1   11170301021051           570 HIGHWAY 231 NORTH, VINCENT, AL 35178
# 2   11010060001057          3017 BIRMINGHAM HWY, MONTGOMERY, AL 36108
# 3   60375021002013  12504 AND 12512 E. WHITTIER BOULEVARD, WHITTIE...
# 4  420659503005008                   ROUTE 950, FALLS CREEK, PA 15840
#
#            city  date_added federal_facility_ind  \
# 0  Childersburg  07/22/1987                  Yes
# 1       Vincent  09/18/2012                   No
# 2    Montgomery  08/30/1990                   No
# 3      Whittier  01/19/1999                   No
# 4   Falls Creek  09/14/2005                   No
#
#                                 federal_register_url geocode_source  \
# 0     https://semspub.epa.gov/src/document/11/189629   full_address
# 1  http://www.gpo.gov/fdsys/pkg/FR-2012-09-18/pdf...   full_address
# 2     https://semspub.epa.gov/src/document/11/189637   full_address
# 3  http://www.gpo.gov/fdsys/pkg/FR-1999-01-19/pdf...   full_address
# 4  http://www.gpo.gov/fdsys/pkg/FR-2005-09-14/pdf...   full_address
#
#     latitude   longitude   site_epa_id  ... pct_TEA_MailOutMailBack_CEN_2010  \
# 0  33.286432  -86.358807  AL6210020008  ...                           100.00
# 1  33.399231  -86.404985  ALD004022448  ...                           100.00
# 2  32.367036  -86.372935  ALD007454085  ...                           100.00
# 3  33.969447 -118.043443  CAD042245001  ...                           100.00
# 4  41.145061  -78.804365  PAD001222025  ...                            46.31
#
#   pct_TEA_Update_Leave_CEN_2010 pct_Census_Mail_Returns_CEN_2010  \
# 0                          0.00                            74.03
# 1                          0.00                            55.28
# 2                          0.00                            27.33
# 3                          0.00                            72.02
# 4                         53.69                            73.60
#
#    pct_Vacant_CEN_2010 pct_Deletes_CEN_2010  pct_Census_UAA_CEN_2010  \
# 0                 3.58                  0.0                    10.90
# 1                 2.44                  0.0                    31.06
# 2                 2.84                  0.0                    54.19
# 3                 1.46                  0.0                     3.58
# 4                 4.03                  4.7                     3.80
#
#    pct_Mailback_Count_CEN_2010 pct_FRST_FRMS_CEN_2010  \
# 0                        85.52                  67.16
# 1                        66.50                  48.62
# 2                        42.97                  23.06
# 3                        94.96                  72.02
# 4                        87.47                  71.59
#
#    pct_RPLCMNT_FRMS_CEN_2010 pct_BILQ_Mailout_count_CEN_2010
# 0                       6.87                            0.00
# 1                       6.67                            0.00
# 2                       4.27                            0.00
# 3                       0.00                           97.88
# 4                       2.01                            0.00
#
# [5 rows x 359 columns]

# %% [markdown]
# ### Export the dataframe as a csv for manual inspection

# %%
superfund_sites_df.to_csv("Datasets/priorities_list_full.csv", index = False)

# %% [markdown]
# ## Cleaning the Data

# %% [markdown]
# ### Define the desired columns
# The columns listed below were selected for potential visualization.

# %%
# Create a filtered dataframe from specific columns
desired_columns = ["address",
                "city",
                "latitude",
                "longitude",
                "site_score",
                "text",
                "State_name",
                "County_name",
                "Tract",
                "Block_Group",
                "Tot_Population_CEN_2010",
                "Hispanic_CEN_2010",
                "NH_Blk_alone_CEN_2010",
                "NH_AIAN_alone_CEN_2010",
                "NH_Asian_alone_CEN_2010",
                "NH_NHOPI_alone_CEN_2010",
                "NH_SOR_alone_CEN_2010",
                "College_ACS_09_13",
                "No_Health_Ins_ACS_09_13",
                "Med_HHD_Inc_BG_ACS_09_13",
                "Aggregate_HH_INC_ACS_09_13",
                "Tot_Vacant_Units_CEN_2010",
                "Renter_Occp_HU_CEN_2010",
                "Owner_Occp_HU_CEN_2010",
                "No_Plumb_ACS_09_13",
                "Med_House_Value_BG_ACS_09_13",
                "pct_Hispanic_CEN_2010",
                "pct_NH_Blk_alone_CEN_2010",
                "pct_NH_AIAN_alone_CEN_2010",
                "pct_NH_Asian_alone_CEN_2010",
                "pct_NH_NHOPI_alone_CEN_2010",
                "pct_NH_SOR_alone_CEN_2010",
                "pct_Not_HS_Grad_ACS_09_13",
                "pct_No_Health_Ins_ACS_09_13",
                "pct_Vacant_Units_CEN_2010",
                "pct_Renter_Occp_HU_CEN_2010",
                "pct_Owner_Occp_HU_CEN_2010",
                "pct_No_Plumb_ACS_09_13"]

# %% [markdown]
# ### Create the filtered dataframe

# %%
# pull in the desired columns
superfund_sites_cleaned = superfund_sites_df[desired_columns].copy()

# convert the column names to lowercase to avoid problems with postgreSQL.
superfund_sites_cleaned.columns= superfund_sites_cleaned.columns.str.lower()

# make sure the census block groups and tracts come through as integers
superfund_sites_cleaned.tract = superfund_sites_cleaned.tract.fillna(0.0).astype(int)
superfund_sites_cleaned.block_group = superfund_sites_cleaned.block_group.fillna(0.0).astype(int)

# convert currency strings to floats
superfund_sites_cleaned[['med_hhd_inc_bg_acs_09_13']] = (superfund_sites_cleaned['med_hhd_inc_bg_acs_09_13'].replace( '[\$,)]','', regex=True )
                     .replace( '[(]','-',   regex=True ).astype(float))

superfund_sites_cleaned[['aggregate_hh_inc_acs_09_13']] = (superfund_sites_cleaned['aggregate_hh_inc_acs_09_13'].replace( '[\$,)]','', regex=True )
                     .replace( '[(]','-',   regex=True ).astype(float))

superfund_sites_cleaned[['med_house_value_bg_acs_09_13']] = (superfund_sites_cleaned['med_house_value_bg_acs_09_13'].replace( '[\$,)]','', regex=True )
                     .replace( '[(]','-',   regex=True ).astype(float))

# rename the 'text' column to avoid potential confusion
superfund_sites_cleaned.rename(columns={"text": "site_text"})

# check the head
superfund_sites_cleaned.head()
# Out:
#                                              address          city   latitude  \
# 0              STATE HWY 235, CHILDERSBURG, AL 35044  Childersburg  33.286432
# 1           570 HIGHWAY 231 NORTH, VINCENT, AL 35178       Vincent  33.399231
# 2          3017 BIRMINGHAM HWY, MONTGOMERY, AL 36108    Montgomery  32.367036
# 3  12504 AND 12512 E. WHITTIER BOULEVARD, WHITTIE...      Whittier  33.969447
# 4                   ROUTE 950, FALLS CREEK, PA 15840   Falls Creek  41.145061
#
#     longitude  site_score                                               text  \
# 0  -86.358807       36.83  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...
# 1  -86.404985       30.20  NATIONAL PRIORITIES LIST (NPL) SITE LISTING NA...
# 2  -86.372935       44.46  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...
# 3 -118.043443       30.94  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...
# 4  -78.804365       30.22  NATIONAL PRIORITIES LIST (NPL) SITE LISTING NA...
#
#      state_name         county_name   tract  block_group  ...  \
# 0       Alabama    Talladega County   11300            1  ...
# 1       Alabama       Shelby County   30102            1  ...
# 2       Alabama   Montgomery County    6000            1  ...
# 3    California  Los Angeles County  502100            2  ...
# 4  Pennsylvania    Jefferson County  950300            5  ...
#
#    pct_nh_aian_alone_cen_2010  pct_nh_asian_alone_cen_2010  \
# 0                        0.07                         0.21
# 1                        0.29                         0.00
# 2                        0.00                         0.00
# 3                        0.42                         1.69
# 4                        0.20                         0.20
#
#    pct_nh_nhopi_alone_cen_2010  pct_nh_sor_alone_cen_2010  \
# 0                         0.00                       0.14
# 1                         0.00                       0.00
# 2                         0.00                       0.11
# 3                         0.04                       0.08
# 4                         0.00                       0.00
#
#    pct_not_hs_grad_acs_09_13  pct_no_health_ins_acs_09_13  \
# 0                      17.62                         5.32
# 1                      30.23                        14.50
# 2                      50.87                        33.92
# 3                      31.43                        22.99
# 4                       7.70                        10.70
#
#    pct_vacant_units_cen_2010  pct_renter_occp_hu_cen_2010  \
# 0                      12.89                        19.02
# 1                       9.02                        16.00
# 2                      24.11                        33.11
# 3                       3.60                        61.83
# 4                       7.53                        27.91
#
#    pct_owner_occp_hu_cen_2010  pct_no_plumb_acs_09_13
# 0                       80.98                    0.00
# 1                       84.00                    7.02
# 2                       66.89                    0.00
# 3                       38.17                    3.52
# 4                       72.09                    2.06
#
# [5 rows x 38 columns]

# %% [markdown]
# ### Create a list of column types
# A list of column types is useful for checking against the database table. (We need to verify that there are no surprises, like currency stored as a string.)

# %%
superfund_cleaned_column_types = list(superfund_sites_cleaned.dtypes)
dtype_reference = list(zip(superfund_sites_cleaned.columns.values, superfund_cleaned_column_types))
dtype_reference
# Out:
# [('address', dtype('O')),
#  ('city', dtype('O')),
#  ('latitude', dtype('float64')),
#  ('longitude', dtype('float64')),
#  ('site_score', dtype('float64')),
#  ('text', dtype('O')),
#  ('state_name', dtype('O')),
#  ('county_name', dtype('O')),
#  ('tract', dtype('int32')),
#  ('block_group', dtype('int32')),
#  ('tot_population_cen_2010', dtype('float64')),
#  ('hispanic_cen_2010', dtype('float64')),
#  ('nh_blk_alone_cen_2010', dtype('float64')),
#  ('nh_aian_alone_cen_2010', dtype('float64')),
#  ('nh_asian_alone_cen_2010', dtype('float64')),
#  ('nh_nhopi_alone_cen_2010', dtype('float64')),
#  ('nh_sor_alone_cen_2010', dtype('float64')),
#  ('college_acs_09_13', dtype('float64')),
#  ('no_health_ins_acs_09_13', dtype('float64')),
#  ('med_hhd_inc_bg_acs_09_13', dtype('float64')),
#  ('aggregate_hh_inc_acs_09_13', dtype('float64')),
#  ('tot_vacant_units_cen_2010', dtype('float64')),
#  ('renter_occp_hu_cen_2010', dtype('float64')),
#  ('owner_occp_hu_cen_2010', dtype('float64')),
#  ('no_plumb_acs_09_13', dtype('float64')),
#  ('med_house_value_bg_acs_09_13', dtype('float64')),
#  ('pct_hispanic_cen_2010', dtype('float64')),
#  ('pct_nh_blk_alone_cen_2010', dtype('float64')),
#  ('pct_nh_aian_alone_cen_2010', dtype('float64')),
#  ('pct_nh_asian_alone_cen_2010', dtype('float64')),
#  ('pct_nh_nhopi_alone_cen_2010', dtype('float64')),
#  ('pct_nh_sor_alone_cen_2010', dtype('float64')),
#  ('pct_not_hs_grad_acs_09_13', dtype('float64')),
#  ('pct_no_health_ins_acs_09_13', dtype('float64')),
#  ('pct_vacant_units_cen_2010', dtype('float64')),
#  ('pct_renter_occp_hu_cen_2010', dtype('float64')),
#  ('pct_owner_occp_hu_cen_2010', dtype('float64')),
#  ('pct_no_plumb_acs_09_13', dtype('float64'))]

# %% [markdown]
# ### Export the cleaned dataframe to csv for inspection

# %%
superfund_sites_cleaned.to_csv("Datasets/priorities_list_full_cleaned.csv", index = False)

# %% [markdown]
# ## Load the Data

# %% [markdown]
# ### Connect to the database

# %%
rds_connection_string = "postgres:postgres@localhost:5432/project_2_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['superfund_data_table']

# %% [markdown]
# ### Load the cleaned dataframe into the database

# %%
superfund_sites_cleaned.to_sql(name='superfund_data_table', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm the Load

# %%
pd.read_sql_query('select * from superfund_data_table', con=engine).head()
# Out:
#    id                                            address          city  \
# 0   1              STATE HWY 235, CHILDERSBURG, AL 35044  Childersburg
# 1   2           570 HIGHWAY 231 NORTH, VINCENT, AL 35178       Vincent
# 2   3          3017 BIRMINGHAM HWY, MONTGOMERY, AL 36108    Montgomery
# 3   4  12504 AND 12512 E. WHITTIER BOULEVARD, WHITTIE...      Whittier
# 4   5                   ROUTE 950, FALLS CREEK, PA 15840   Falls Creek
#
#     latitude   longitude  site_score  \
# 0  33.286432  -86.358807       36.83
# 1  33.399231  -86.404985       30.20
# 2  32.367036  -86.372935       44.46
# 3  33.969447 -118.043443       30.94
# 4  41.145061  -78.804365       30.22
#
#                                                 text    state_name  \
# 0  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...       Alabama
# 1  NATIONAL PRIORITIES LIST (NPL) SITE LISTING NA...       Alabama
# 2  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...       Alabama
# 3  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...    California
# 4  NATIONAL PRIORITIES LIST (NPL) SITE LISTING NA...  Pennsylvania
#
#           county_name   tract  ...  pct_nh_aian_alone_cen_2010  \
# 0    Talladega County   11300  ...                        0.07
# 1       Shelby County   30102  ...                        0.29
# 2   Montgomery County    6000  ...                        0.00
# 3  Los Angeles County  502100  ...                        0.42
# 4    Jefferson County  950300  ...                        0.20
#
#    pct_nh_asian_alone_cen_2010  pct_nh_nhopi_alone_cen_2010  \
# 0                         0.21                         0.00
# 1                         0.00                         0.00
# 2                         0.00                         0.00
# 3                         1.69                         0.04
# 4                         0.20                         0.00
#
#    pct_nh_sor_alone_cen_2010  pct_not_hs_grad_acs_09_13  \
# 0                       0.14                      17.62
# 1                       0.00                      30.23
# 2                       0.11                      50.87
# 3                       0.08                      31.43
# 4                       0.00                       7.70
#
#    pct_no_health_ins_acs_09_13  pct_vacant_units_cen_2010  \
# 0                         5.32                      12.89
# 1                        14.50                       9.02
# 2                        33.92                      24.11
# 3                        22.99                       3.60
# 4                        10.70                       7.53
#
#    pct_renter_occp_hu_cen_2010  pct_owner_occp_hu_cen_2010  \
# 0                        19.02                       80.98
# 1                        16.00                       84.00
# 2                        33.11                       66.89
# 3                        61.83                       38.17
# 4                        27.91                       72.09
#
#    pct_no_plumb_acs_09_13
# 0                    0.00
# 1                    7.02
# 2                    0.00
# 3                    3.52
# 4                    2.06
#
# [5 rows x 39 columns]
